# %%
# !pip uninstall tensorflow -y
# !pip install tensorflow==2.14

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Layer
import keras.backend as kb

# %% [markdown]
# ### Custum objects for Progressive GAN

# %%
def _pixel_norm(x, epsilon=1e-8, channel_axis=-1):
  return x * tf.math.rsqrt(tf.reduce_mean(tf.square(x), axis=channel_axis, keepdims=True) + epsilon)

class PixelNorm(Layer):
  def __init__(self, channel_axis=-1, **kwargs):
    self.channel_axis = channel_axis
    super().__init__()

  def call(self, x):
    return _pixel_norm(x, channel_axis=self.channel_axis)

  def compute_output_shape(self, input_shape):
    return input_shape

  def get_config(self):
    return {
        'channel_axis': self.channel_axis,
        **super().get_config()
    }


def _upscale2d(x, factor=2):
  # Channels last upscale
  assert isinstance(factor, int) and factor >= 1
  if factor == 1: return x

  s = x.shape
  x = tf.reshape(x, [-1, s[1], 1, s[2], 1, s[3]])
  x = tf.tile(x, [1, 1, 1, factor, factor, 1])
  x = tf.reshape(x, [-1, s[1] * factor, s[2] * factor, s[3]])
  return x

class Upscale2D(Layer):

  def call(self, x):
    return _upscale2d(x)

  def compute_output_shape(self, input_shape):
    batch_size, h, w, c = input_shape
    output_shape = [batch_size, h*2, w*2, c]
    return tuple(output_shape)


class ToChannelsLast(Layer):

  def call(self, x):
    return kb.permute_dimensions(x, [0, 2, 3, 1])

  def compute_output_shape(self, input_shape):
    batch_size, c, h, w = input_shape
    output_shape = [batch_size, h, w, c]
    return tuple(output_shape)

custom_objects = {
  'Upscale2D': Upscale2D,
  'PixelNorm': PixelNorm,
  'ToChannelsLast': ToChannelsLast,
}

# %% [markdown]
# ### Load pretrained models

# %%
# !wget -q -O classifier.h5  "https://seafile.unistra.fr/f/318cced7f9ab48e1976b/?dl=1"
# !wget -q -O keras_progan.hdf5 "https://seafile.unistra.fr/f/61673b835ac84c47a808/?dl=1"

# %%
cls = load_model('classifier.h5')
progan = load_model('keras_progan.hdf5', custom_objects=custom_objects)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Test ProGAN model

# %%
latents = np.random.RandomState(1000).randn(1000, 512) # 1000 random latents
latents = latents[[477, 56]] # hand-picked top-10 from the authors, to verify replication.

imgs = progan.predict(latents)
# Predicts in range -1 to 1
imgs = (imgs + 1) / 2 # Now 0 to 1
imgs = np.clip(imgs, 0, 1)

plt.imshow(imgs[0])
plt.axis('off')
plt.savefig('test.jpg')
plt.figure()
plt.imshow(imgs[1])
plt.axis('off')
plt.savefig('test.jpg')
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
progan.summary()
# Out:
# Model: "model_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_14 (InputLayer)       [(None, 512)]             0
#
#  pixel_norm (PixelNorm)      (None, 512)               0
#
#  dense_9 (Dense)             (None, 8192)              4202496
#
#  reshape_9 (Reshape)         (None, 512, 4, 4)         0
#
#  leaky_re_lu_129 (LeakyReLU  (None, 512, 4, 4)         0
#  )
#
#  pixel_norm_1 (PixelNorm)    (None, 512, 4, 4)         0
#
#  to_channels_last_9 (ToChan  (None, 4, 4, 512)         0
#  nelsLast)
#
#  conv2d_128 (Conv2D)         (None, 4, 4, 512)         2359808
#
#  leaky_re_lu_130 (LeakyReLU  (None, 4, 4, 512)         0
#  )
#
#  pixel_norm_2 (PixelNorm)    (None, 4, 4, 512)         0
#
#  upscale2d_58 (Upscale2D)    (None, 8, 8, 512)         0
#
#  conv2d_129 (Conv2D)         (None, 8, 8, 512)         2359808
#
#  leaky_re_lu_131 (LeakyReLU  (None, 8, 8, 512)         0
#  )
#
#  pixel_norm_3 (PixelNorm)    (None, 8, 8, 512)         0
#
#  conv2d_130 (Conv2D)         (None, 8, 8, 512)         2359808
#
#  leaky_re_lu_132 (LeakyReLU  (None, 8, 8, 512)         0
#  )
#
#  pixel_norm_4 (PixelNorm)    (None, 8, 8, 512)         0
#
#  upscale2d_59 (Upscale2D)    (None, 16, 16, 512)       0
#
#  conv2d_131 (Conv2D)         (None, 16, 16, 512)       2359808
#
#  leaky_re_lu_133 (LeakyReLU  (None, 16, 16, 512)       0
#  )
#
#  pixel_norm_5 (PixelNorm)    (None, 16, 16, 512)       0
#
#  conv2d_132 (Conv2D)         (None, 16, 16, 512)       2359808
#
#  leaky_re_lu_134 (LeakyReLU  (None, 16, 16, 512)       0
#  )
#
#  pixel_norm_6 (PixelNorm)    (None, 16, 16, 512)       0
#
#  upscale2d_60 (Upscale2D)    (None, 32, 32, 512)       0
#
#  conv2d_133 (Conv2D)         (None, 32, 32, 512)       2359808
#
#  leaky_re_lu_135 (LeakyReLU  (None, 32, 32, 512)       0
#  )
#
#  pixel_norm_7 (PixelNorm)    (None, 32, 32, 512)       0
#
#  conv2d_134 (Conv2D)         (None, 32, 32, 512)       2359808
#
#  leaky_re_lu_136 (LeakyReLU  (None, 32, 32, 512)       0
#  )
#
#  pixel_norm_8 (PixelNorm)    (None, 32, 32, 512)       0
#
#  upscale2d_61 (Upscale2D)    (None, 64, 64, 512)       0
#
#  conv2d_135 (Conv2D)         (None, 64, 64, 256)       1179904
#
#  leaky_re_lu_137 (LeakyReLU  (None, 64, 64, 256)       0
#  )
#
#  pixel_norm_9 (PixelNorm)    (None, 64, 64, 256)       0
#
#  conv2d_136 (Conv2D)         (None, 64, 64, 256)       590080
#
#  leaky_re_lu_138 (LeakyReLU  (None, 64, 64, 256)       0
#  )
#
#  pixel_norm_10 (PixelNorm)   (None, 64, 64, 256)       0
#
#  upscale2d_62 (Upscale2D)    (None, 128, 128, 256)     0
#
#  conv2d_137 (Conv2D)         (None, 128, 128, 128)     295040
#
#  leaky_re_lu_139 (LeakyReLU  (None, 128, 128, 128)     0
#  )
#
#  pixel_norm_11 (PixelNorm)   (None, 128, 128, 128)     0
#
#  conv2d_138 (Conv2D)         (None, 128, 128, 128)     147584
#
#  leaky_re_lu_140 (LeakyReLU  (None, 128, 128, 128)     0
#  )
#
#  pixel_norm_12 (PixelNorm)   (None, 128, 128, 128)     0
#
#  upscale2d_63 (Upscale2D)    (None, 256, 256, 128)     0
#
#  conv2d_139 (Conv2D)         (None, 256, 256, 64)      73792
#
#  leaky_re_lu_141 (LeakyReLU  (None, 256, 256, 64)      0
#  )
#
#  pixel_norm_13 (PixelNorm)   (None, 256, 256, 64)      0
#
#  conv2d_140 (Conv2D)         (None, 256, 256, 64)      36928
#
#  leaky_re_lu_142 (LeakyReLU  (None, 256, 256, 64)      0
#  )
#
#  pixel_norm_14 (PixelNorm)   (None, 256, 256, 64)      0
#
#  upscale2d_64 (Upscale2D)    (None, 512, 512, 64)      0
#
#  conv2d_141 (Conv2D)         (None, 512, 512, 32)      18464
#
#  leaky_re_lu_143 (LeakyReLU  (None, 512, 512, 32)      0
#  )
#
#  pixel_norm_15 (PixelNorm)   (None, 512, 512, 32)      0
#
#  conv2d_142 (Conv2D)         (None, 512, 512, 32)      9248
#
#  leaky_re_lu_144 (LeakyReLU  (None, 512, 512, 32)      0
#  )
#
#  pixel_norm_16 (PixelNorm)   (None, 512, 512, 32)      0
#
#  upscale2d_65 (Upscale2D)    (None, 1024, 1024, 32)    0
#
#  conv2d_143 (Conv2D)         (None, 1024, 1024, 16)    4624
#
#  leaky_re_lu_145 (LeakyReLU  (None, 1024, 1024, 16)    0
#  )
#
#  pixel_norm_17 (PixelNorm)   (None, 1024, 1024, 16)    0
#
#  conv2d_144 (Conv2D)         (None, 1024, 1024, 16)    2320
#
#  leaky_re_lu_146 (LeakyReLU  (None, 1024, 1024, 16)    0
#  )
#
#  pixel_norm_18 (PixelNorm)   (None, 1024, 1024, 16)    0
#
#  conv2d_145 (Conv2D)         (None, 1024, 1024, 3)     51
#
# =================================================================
# Total params: 23079187 (88.04 MB)
# Trainable params: 23079187 (88.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Display function

# %%
import matplotlib.pyplot as plt

def display_images(images, captions=None):
  num_ver = 1
  num_hor = 8
  plt.figure(figsize=(20,20))
  for i in range(len(images)):
    plt.subplot(num_ver,num_hor, i + 1)
    plt.imshow((images[i]*255).astype('uint8'))
    plt.axis('off')

  plt.tight_layout()

# %% [markdown]
# ### Global variables

# %%
# Globals variables :
shape=[128,128]
feature_names   = ['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry',
                 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male',
                 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks',
                 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young']

# %%
#TODO:
weight = 0.01
n_images = 2
tf.random.set_seed(110)
noise = tf.Variable(tf.random.normal(mean=0,stddev=0.1,shape=(n_images, 512)),trainable=True)
grad_step = 5
fake_image_history = []
target_indices = feature_names.index("Smiling")
for i in range(grad_step):
  print(i)
  with tf.GradientTape() as tape:
    tape.watch(noise)
    fake_image = ((progan(noise)+1)/2)
    fake_image = tf.image.resize(fake_image,[shape[0],shape[1]])
    pred = tf.math.reduce_mean(cls(fake_image)[:, target_indices])

  grad = tape.gradient(pred,noise)
  noise.assign_add(grad*weight)
  #noise.assign_add(grad*(1/(i+1)))


  fake_image_history += [fake_image]
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(0,grad_step,1):
  display_images(fake_image_history[i].numpy())

# %% [markdown]
# ### Playground
#
#
#
# 1.   Change feature (see feature_names)
# 2.   Change learning rate (weight variable)
# 3.   Change number of gradinet steps
# 3.   Observe entanglemnt in latent space
